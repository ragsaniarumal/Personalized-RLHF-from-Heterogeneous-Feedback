# %% [markdown]
# # Historical course results
#
# This notebook visualizes the result table retained from the CS-6103 presentation. It does not claim to reproduce the lost GPT-J/LLaMA checkpoints.

# %%
import pandas as pd
from pathlib import Path
results = pd.read_csv(Path('..') / 'experiments' / 'historical_results.csv')
results

# %%
results.assign(
    gptj_delta=results.gptj_course-results.gptj_original,
    llama3_delta=results.llama3_course-results.llama3_original,
)[['method','gptj_delta','llama3_delta']]
